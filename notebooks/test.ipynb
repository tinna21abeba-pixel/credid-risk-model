# %%
import pandas as pd
import sys
import os
import importlib

project_root = os.path.abspath("..")
sys.path.append(project_root)

import src.data_processing
importlib.reload(src.data_processing)

from src.data_processing import pipeline
from src.data_processing import process_transactions
print("imported succesfully")
# correct path to data file
df = pd.read_csv("../data/raw/data.csv")

X = pipeline.fit_transform(df)

print(X.shape)

processed_df.describe()
# Out:
# imported succesfully
# (59, 24)
#        CountryCode        Amount         Value  PricingStrategy  FraudResult  \
# count         59.0     59.000000     59.000000        59.000000         59.0
# mean         256.0   3387.148305   3549.338983         2.118644          0.0
# std            0.0   7141.702787   7192.660178         0.528000          0.0
# min          256.0   -644.000000     10.000000         1.000000          0.0
# 25%          256.0    -22.500000    498.000000         2.000000          0.0
# 50%          256.0   1000.000000   1000.000000         2.000000          0.0
# 75%          256.0   2850.000000   2850.000000         2.000000          0.0
# max          256.0  41000.000000  41000.000000         4.000000          0.0
#
#        is_high_risk
# count     59.000000
# mean       0.762712
# std        0.429072
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
